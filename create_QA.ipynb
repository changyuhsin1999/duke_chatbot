# %%
import requests
from bs4 import BeautifulSoup

# URL to scrape
url = "https://sites.duke.edu/prattgsps/safety-at-duke/"

# Send a GET request to the website
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Extract the text from the webpage
    text = soup.get_text()

    print(text)

else:
    print("Failed to retrieve the webpage")
# Out:
# Safety at Duke – Graduate Student Programs and Services
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Skip to content
#
#
#
#
#
#
#
# 						Graduate Student Programs and Services
#
#
# Search
#
#
#
#
#
#
#
# Search
#
#
#
#
#
#
#
# 						Menu
#
#
#
#
#
#
# WHO WE ARE
#
# GSPS Directory
# Career Services for Master’s Students
# Career Services for PhD Students
# Graduate Communications and Intercultural Programs
# Student Engagement and Support
#
#
# New Student Information
#
# Welcome Fall 2024 Students
# New Student Checklist
# Summer Transition Series
# Summer Language Intensive Communication Experience
# International Student Resources
# Safety and Support Resources
# Employment Options
#
#
# Student Life
#
# Engineering Master’s Student Advisory Board
# Engineering Graduate Student Council
# PhD Plus Student Executive Board
# Pratt Peers Student Support Network
# Student-Led Event Planning Checklist
# University-Wide Leadership Opportunities
# ...

# %%
# Define the file path and name
file_path = 'data/safety_at_duke.txt'

# Open the file in write mode ('w') or append mode ('a') as needed
with open(file_path, 'w', encoding='utf-8') as file:
    # Write the extracted text to the file
    file.write(text)

print(f"Text has been saved to {file_path}")
# Out:
# Text has been saved to data/safety_at_duke.txt

# %%
import json
import os
import openai
from openai import OpenAI

# Placeholder for your OpenAI API key


def process_text_file(file_path):
    """
    Reads a text file and returns its content.
    """
    with open(file_path, 'r', encoding='utf-8') as file:
        content = file.read()
    return content

def process_json_file(file_path):
    """
    Reads a JSON file and returns a combined string of its values (assuming it's a dictionary).
    """
    with open(file_path, 'r', encoding='utf-8') as file:
        data = json.load(file)
    # Assuming the JSON file is a dictionary; concatenate its values for processing
    content = ' '.join([str(value) for value in data.values()])
    return content

def generate_questions_answers(data):
    """
    Generates questions and answers based on the data provided.
    """
    client = OpenAI(api_key='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')

    # Extract response
    # This is a simplified example. Adapt this logic to fit your data structure and requirements.
    questions_answers = []
    for item in data:  # Assume 'data' is a list of items you want to generate Q&A for
        # Create prompt
        response = client.chat.completions.create(
        model="gpt-3.5-turbo",
        messages=[
        {"role": "system", "content": "You are a helpful ambassador for Duke University Artificial Intelligence program please generate question and answer pairs based on the information given"},
        {"role": "user", "content": "Using information given, please generate 200 questions and answer pairs. Make sure you follow the format of Question:... Answer:... Please provide detail answers and link if needed"}])
        # split response to Question and Answer pair
        print(response.choices[0].message.content)
        pairs = response.choices[0].message.content.split("\n\n")
        for pair in pairs:
            split_pair = pair.split("\n")
            if len(split_pair) >= 2:
                question = split_pair[0].replace("Question: ", "").strip()
                answer = split_pair[1].replace("Answer: ", "").strip()
                qa_pair = {"question": question, "answer": answer}
                questions_answers.append(qa_pair)
    return questions_answers

def save_to_json(data, file_path):
    """
    Saves the provided data to a JSON file.
    """
    with open(file_path, 'w', encoding='utf-8') as file:
        json.dump(data, file, ensure_ascii=False, indent=4)

def read_files(directory_path):
    """
    Reads all text and JSON files in the specified directory and returns their contents.
    """
    files_contents = []
    for filename in os.listdir(directory_path):
        file_path = os.path.join(directory_path, filename)
        if filename.endswith(".txt"):
            content = process_text_file(file_path)
            files_contents.append(content)
        elif filename.endswith(".json"):
            content = process_json_file(file_path)
            files_contents.append(content)
    return files_contents

def main():
    directory_path = 'data_dir'
    output_file_path = 'Question_Answer_pairs.json'
    data = read_files(directory_path)
    
    questions_answers = generate_questions_answers(data)
    
    save_to_json(questions_answers, output_file_path)
    print(f"Saved {len(questions_answers)} Q&A pairs to {output_file_path}")

if __name__ == "__main__":
    main()
# Out:
# Question: What is Duke University known for in the field of Artificial Intelligence?
# Answer: Duke University is known for its cutting-edge research and education programs in Artificial Intelligence, leveraging state-of-the-art technology and collaborations with industry leaders to advance the field.
#
# Question: Can students pursue a degree in Artificial Intelligence at Duke University?
# Answer: Yes, students at Duke University can pursue undergraduate and graduate degrees in Artificial Intelligence through programs such as Computer Science and Electrical & Computer Engineering.
#
# Question: How does Duke University prepare students for careers in Artificial Intelligence?
# Answer: Duke University prepares students for careers in Artificial Intelligence through hands-on research opportunities, internships with industry partners, and a strong curriculum that covers key AI concepts and applications.
#
# ...
